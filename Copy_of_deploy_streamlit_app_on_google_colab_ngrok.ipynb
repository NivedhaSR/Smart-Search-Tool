# %% [markdown]
# <a href="https://colab.research.google.com/github/NivedhaSR/Smart-Search-Tool/blob/main/Copy_of_deploy_streamlit_app_on_google_colab_ngrok.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/NivedhaSR/Smart-Search-Tool.git
# Out:
# Cloning into 'Smart-Search-Tool'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 14 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (14/14), 273.42 KiB | 2.65 MiB/s, done.

# %%
# Step 1: Install the necessary packages
# !pip install pyngrok

# !pip install -r "/content/Smart-Search-Tool/requirements.txt"
# Out:
# ...
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: '/Smart-Search-LLM-main/requirements.txt'

# %%
# !pip install -r "Smart-Search-Tool/Smart-Search-LLM-main/requirements.txt"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 5.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 44.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 408.7/408.7 kB 29.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 40.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 59.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 kB 15.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.7/56.7 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.1/41.1 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 615.5/615.5 kB 41.1 MB/s eta 0:00:00
# ...

# %%
import os
from threading import Thread
from pyngrok import ngrok

# %%
# Add your ngrok token here
ngrok.set_auth_token('2ofNTWTLgCwz024th0APvyYowwe_6rEaFodGVXAC3bNaodfq7')

# %%
def run_streamlit():
    # Change the port if 8501 is already in use or if you prefer another port
    os.system('streamlit run Smart-Search-Tool/Smart-Search-LLM-main/app.py --server.port 8501')

# %%
# Start a thread to run the Streamlit app
thread = Thread(target=run_streamlit)
thread.start()

# %%
# Open a tunnel to the streamlit port 8501
public_url = ngrok.connect(addr='8501', proto='http', bind_tls=True)
print('Your Streamlit app is live at:', public_url)
# Out:
# Your Streamlit app is live at: NgrokTunnel: "https://3cd7-34-168-168-210.ngrok-free.app" -> "http://localhost:8501"

# %%
ngrok.kill()
